# %%
import pandas as pd
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

# %%
df = pd.read_csv('all_stocks_5yr.csv', index_col='date', parse_dates=['date'])

# %%
df.head()
# Out:
#              open   high    low  close    volume Name
# date
# 2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
stocks = list(set(df.Name))

# %%
df[df.Name == 'AAPL']
# Out:
#                 open      high       low     close     volume  Name
# date
# 2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# ...              ...       ...       ...       ...        ...   ...
# 2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL
# 2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL
# 2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL
# 2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL
# 2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL
#
# [1259 rows x 6 columns]

# %%
df_aapl = df[df.Name == 'AAPL']
df_aapl
# Out:
#                 open      high       low     close     volume  Name
# date
# 2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# ...              ...       ...       ...       ...        ...   ...
# 2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL
# 2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL
# 2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL
# 2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL
# 2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL
#
# [1259 rows x 6 columns]

# %%
df_aapl.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_aapl[['open', 'high']].plot(figsize=(8,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# %matplotlib nbagg

# %%
df.head()
# Out:
#              open   high    low  close    volume Name
# date
# 2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
df_aapl
# Out:
#                 open      high       low     close     volume  Name
# date
# 2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# ...              ...       ...       ...       ...        ...   ...
# 2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL
# 2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL
# 2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL
# 2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL
# 2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL
#
# [1259 rows x 6 columns]

# %%
win_len = 10
ax = df_aapl['open'].plot(figsize=(7, 4), title='AAPL Open Price')
df_aapl_roll = df_aapl.rolling(win_len).mean()
df_aapl_roll.head(50)
#plt.tight_layout()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
# C:\Users\20100428\AppData\Local\Temp\ipykernel_11964\288309483.py:3: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Name'], dtype='object')
#   df_aapl_roll = df_aapl.rolling(win_len).mean()
#                 open      high       low     close       volume
# date
# 2013-02-08       NaN       NaN       NaN       NaN          NaN
# 2013-02-11       NaN       NaN       NaN       NaN          NaN
# 2013-02-12       NaN       NaN       NaN       NaN          NaN
# 2013-02-13       NaN       NaN       NaN       NaN          NaN
# 2013-02-14       NaN       NaN       NaN       NaN          NaN
# 2013-02-15       NaN       NaN       NaN       NaN          NaN
# 2013-02-19       NaN       NaN       NaN       NaN          NaN
# ...

# %%
df['Gain'] = df['close'] - df['open']

# %%
df['Rolling Close Average'] = df['close'].rolling(2).mean()

# %%
df['Rolling Close Average']
# Out:
# date
# 2013-02-08       NaN
# 2013-02-11    14.605
# 2013-02-12    14.365
# 2013-02-13    14.465
# 2013-02-14    14.325
#                ...
# 2018-02-01    77.275
# 2018-02-02    77.300
# 2018-02-05    75.305
# 2018-02-06    73.550
# 2018-02-07    73.565
# Name: Rolling Close Average, Length: 619040, dtype: float64

# %%
df['Open Standard Deviation'] = df['open'].std()
df['Rolling Open Standard Deviation'] = df['open'].rolling(2).std()
df
# Out:
#              open   high    low  close    volume Name  Gain  \
# date
# 2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL -0.32
# 2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL -0.43
# 2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL -0.18
# 2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL  0.36
# 2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL -0.95
# ...           ...    ...    ...    ...       ...  ...   ...
# 2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS  0.98
# 2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS -0.75
# 2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS -2.81
# 2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS  0.53
# 2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS  1.16
#
#             Rolling Close Average  Open Standard Deviation  \
# date
# 2013-02-08                    NaN                97.378769
# 2013-02-11                 14.605                97.378769
# ...

# %%
df['Rolling Volume Sum'] = df['volume'].rolling(3).sum()
df
# Out:
#              open   high    low  close    volume Name  Gain  \
# date
# 2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL -0.32
# 2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL -0.43
# 2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL -0.18
# 2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL  0.36
# 2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL -0.95
# ...           ...    ...    ...    ...       ...  ...   ...
# 2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS  0.98
# 2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS -0.75
# 2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS -2.81
# 2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS  0.53
# 2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS  1.16
#
#             Rolling Close Average  Open Standard Deviation  \
# date
# 2013-02-08                    NaN                97.378769
# 2013-02-11                 14.605                97.378769
# ...
